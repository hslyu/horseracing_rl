# %% [markdown]
# ## Fetch XML data from data.go.kr

# %%
import requests
import json
import xmltodict

# %%
def download_horse_ability(filters: list = ['hrEngNm', 'rnCnt', 'fstCnt', 'sndCnt', 'trdCnt', 'forthCnt', 
                                        'fifthCnt', 'outCnt', 'amt', 'condAmt', 'winRate', 'quinRate', 'avgWinDist']):
    horse_ability_url = 'http://apis.data.go.kr/B551015/API42/totalHorseInfo'

    page = 1

    horse_abilities = {}
    while True:
        print(f'Downloading page {page}')

        horse_ability_params = {'serviceKey' : service_key, 'pageNo' : str(page), 'numOfRows' : '5000' }

        response = requests.get(horse_ability_url, params=horse_ability_params)
        if response.status_code != 200:
            raise ConnectionError(f'status code not 200. Failed with code {response.status_code}')

        horse_ability_xml = response.content.decode('utf8')

        horse_ability_dict = xmltodict.parse(horse_ability_xml)

        if 'items' not in horse_ability_dict['response']['body'].keys() or horse_ability_dict['response']['body']['items'] is None:
            # If it exceeds the last page, horse_ability will have no items.
            break

        horse_ability_dict_list = horse_ability_dict['response']['body']['items']['item']
        for horse_ability in horse_ability_dict_list:
            horse_ability_filtered = {key: horse_ability[key] for key in horse_ability.keys() if key in filters }
            horse_abilities[horse_ability['hrNo']] = horse_ability_filtered

        page += 1

    print(f'{len(horse_abilities) = }')

    # save horse abilities
    with open('horse_ability.json', 'w') as f:
        json.dump(horse_abilities, f, ensure_ascii=False, indent=4)

# %%
def load_horse_ability(path: str = 'horse_ability.json'):
    # load horse_abilities
    with open(path, 'r') as f:
        horse_ability = json.load(f)
    return horse_ability

# %%
def print_horse(horse: dict, filter_tags: list = None):
    """
    params:
        horse (ElementTree): 
        filter_tags (str or list): tag(s) to print
    return (None)
    """
    # convert str to list
    if isinstance(filter_tags, str):
        filter_tags = [filter_tags]
    for element, value in horse.items():
        if filter_tags is not None:
            if element in filter_tags:
                print(f'{element:10s} {value}')
        else:
            print(f'{element:10s} {value}')

# %% [markdown]
# ### Rearrange the data (group by race, not horse)

# %%
def download_race():
    #service_key = 'uOnq3a%2FhTeOMpTjruRiBY0S4cYo%2BVXoKXXs13PF1CdJkwOOQ2qmNqYphHwsMpDqgprL6zng2R3hO4knPqD8wdA%3D%3D'
    service_key = 'uOnq3a/hTeOMpTjruRiBY0S4cYo+VXoKXXs13PF1CdJkwOOQ2qmNqYphHwsMpDqgprL6zng2R3hO4knPqD8wdA=='

    race_url = 'http://apis.data.go.kr/B551015/API186/SeoulRace'
    race_params ={'serviceKey' : service_key, 'pageNo' : '1', 'numOfRows' : '200', 'rc_date_fr' : '20160101'}
    response = requests.get(race_url, params=race_params)
    race_xml = response.content.decode('utf8')

    race = xmltodict.parse(race_xml)
    horses = race['response']['body']['items']['item']
    
    return horses
    #print(horses[0])
    #print_horse(horses[0], 'hrName')

# %%
def rearrange_horses(horses: dict, horse_abilities: dict, filters : list = ['hrName', 'hrNo', 'meet', 'noracefl', 'rcRank', 'rcDate', 
                                                                       'rcDist', 'rcNo', 'rcOrd', 'rcP1Odd', 'rcP2Odd', 'rcP3Odd']):
    """
    params:
        horse (dict): Race data of the horses
    return races (dict)
    """

    races = {}
    for horse in horses:
        # Horses in rank 06 don't have ratings.
        if horse['rcRank'] == '06':
            continue
        # Get horse ability from horse_abilities
        horse_ability_dict = horse_abilities[horse['hrNo']]
        
        horse_filtered = {key: horse[key] for key in horse.keys() if key in filters }
        horse_filtered.update(horse_ability_dict)
        
        racecode = f"{horse['rcDate']}_{horse['rcNo']}"
        # race code = date_no
        if racecode in races.keys():
            races[racecode].append(horse_filtered)
        else:
            races[racecode] = [horse_filtered]
    return races

# %%
def main():
    horse_abilities = load_horse_ability()
    horses = download_race()

    races = rearrange_horses(horses, horse_abilities)
    
    print(horse_abilities[races['20160102_4'][0]['hrNo']])

    for racecode, horses in races.items():
        print(racecode)
        for horse in horses:
            print_horse(horse)
            print('\n')
# Out:
# 20160102_4
# hrName     트리플샤이닝
# hrNo       036493
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1000
# rcNo       4
# rcOrd      9
# rcP1Odd    8.5
# rcP2Odd    1.8
# rcP3Odd    22.9
# rcRank     04
# amt        58550000
# avgWinDist 0
# condAmt    0
# fifthCnt   1
# forthCnt   1
# fstCnt     0
# hrEngNm    TRIPLE SHINING
# hrNm       트리플샤이닝
# outCnt     5
# quinRate   25
# sndCnt     3
# trdCnt     2
# winRate    0
#
#
# hrName     좌청룡
# hrNo       034743
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1000
# rcNo       4
# rcOrd      12
# rcP1Odd    8.5
# rcP2Odd    1.8
# rcP3Odd    22.9
# rcRank     04
# amt        90600000
# avgWinDist 1700
# condAmt    0
# fifthCnt   1
# forthCnt   3
# fstCnt     1
# hrEngNm    JWACHEONGNYONG
# hrNm       좌청룡
# outCnt     20
# quinRate   6.6
# sndCnt     1
# trdCnt     4
# winRate    3.3
#
#
# hrName     통일대박
# hrNo       032643
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1000
# rcNo       4
# rcOrd      1
# rcP1Odd    8.5
# rcP2Odd    1.8
# rcP3Odd    22.9
# rcRank     04
# amt        121150000
# avgWinDist 1066
# condAmt    50
# fifthCnt   1
# forthCnt   2
# fstCnt     3
# hrEngNm    TONGILDAEBAK
# hrNm       통일대박
# outCnt     11
# quinRate   12.5
# sndCnt     0
# trdCnt     7
# winRate    12.5
#
#
# hrName     어카운트어필
# hrNo       036534
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1000
# rcNo       4
# rcOrd      3
# rcP1Odd    8.5
# rcP2Odd    1.8
# rcP3Odd    22.9
# rcRank     04
# amt        9900000
# avgWinDist 0
# condAmt    0
# fifthCnt   1
# forthCnt   0
# fstCnt     0
# hrEngNm    ACCOUNT APEAL
# hrNm       어카운트어필
# outCnt     3
# quinRate   0
# sndCnt     0
# trdCnt     1
# winRate    0
#
#
# hrName     마두령
# hrNo       036422
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1000
# rcNo       4
# rcOrd      7
# rcP1Odd    8.5
# rcP2Odd    1.8
# rcP3Odd    22.9
# rcRank     04
# amt        105700000
# avgWinDist 1400
# condAmt    0
# fifthCnt   2
# forthCnt   0
# fstCnt     1
# hrEngNm    MADURYEONG
# hrNm       마두령
# outCnt     9
# quinRate   29.4
# sndCnt     4
# trdCnt     1
# winRate    5.8
#
#
# hrName     캐네디언드림
# hrNo       034506
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1000
# rcNo       4
# rcOrd      11
# rcP1Odd    8.5
# rcP2Odd    1.8
# rcP3Odd    22.9
# rcRank     04
# amt        47750000
# avgWinDist 1400
# condAmt    0
# fifthCnt   2
# forthCnt   1
# fstCnt     1
# hrEngNm    Canadian Dream
# hrNm       캐네디언드림
# outCnt     16
# quinRate   9.5
# sndCnt     1
# trdCnt     0
# winRate    4.7
#
#
# hrName     나잇아웃온더타운
# hrNo       036370
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1000
# rcNo       4
# rcOrd      5
# rcP1Odd    8.5
# rcP2Odd    1.8
# rcP3Odd    22.9
# rcRank     04
# amt        109050000
# avgWinDist 1000
# condAmt    0
# fifthCnt   2
# forthCnt   4
# fstCnt     1
# hrEngNm    NIGHTOUTONTHETOWN
# hrNm       나잇아웃온더타운
# outCnt     11
# quinRate   13
# sndCnt     2
# trdCnt     3
# winRate    4.3
#
#
# hrName     혜리온
# hrNo       031536
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1000
# rcNo       4
# rcOrd      8
# rcP1Odd    8.5
# rcP2Odd    1.8
# rcP3Odd    22.9
# rcRank     04
# amt        126050000
# avgWinDist 1000
# condAmt    0
# fifthCnt   2
# forthCnt   1
# fstCnt     3
# hrEngNm    HYERI ON
# hrNm       혜리온
# outCnt     12
# quinRate   20
# sndCnt     2
# trdCnt     5
# winRate    12
#
#
# hrName     스텔스킹
# hrNo       032851
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1000
# rcNo       4
# rcOrd      6
# rcP1Odd    8.5
# rcP2Odd    1.8
# rcP3Odd    22.9
# rcRank     04
# amt        36760000
# avgWinDist 0
# condAmt    0
# fifthCnt   3
# forthCnt   3
# fstCnt     0
# hrEngNm    STEALTH KING
# hrNm       스텔스킹
# outCnt     29
# quinRate   0
# sndCnt     0
# trdCnt     3
# winRate    0
#
#
# hrName     달려라강적
# hrNo       034644
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1000
# rcNo       4
# rcOrd      4
# rcP1Odd    8.5
# rcP2Odd    1.8
# rcP3Odd    22.9
# rcRank     04
# amt        199780000
# avgWinDist 1566
# condAmt    0
# fifthCnt   5
# forthCnt   8
# fstCnt     3
# hrEngNm    DALLYEORA GANGJEOK
# hrNm       달려라강적
# outCnt     7
# quinRate   11.1
# sndCnt     0
# trdCnt     4
# winRate    11.1
#
#
# hrName     전승대세
# hrNo       036491
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1000
# rcNo       4
# rcOrd      2
# rcP1Odd    8.5
# rcP2Odd    1.8
# rcP3Odd    22.9
# rcRank     04
# amt        317350000
# avgWinDist 1400
# condAmt    0
# fifthCnt   2
# forthCnt   4
# fstCnt     2
# hrEngNm    JEONSEUNG DAESE
# hrNm       전승대세
# outCnt     15
# quinRate   27
# sndCnt     8
# trdCnt     6
# winRate    5.4
#
#
# hrName     에코왕자
# hrNo       034655
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1000
# rcNo       4
# rcOrd      10
# rcP1Odd    8.5
# rcP2Odd    1.8
# rcP3Odd    22.9
# rcRank     04
# amt        52850000
# avgWinDist 1200
# condAmt    0
# fifthCnt   0
# forthCnt   0
# fstCnt     1
# hrEngNm    ECO WANGJA
# hrNm       에코왕자
# outCnt     9
# quinRate   16.6
# sndCnt     1
# trdCnt     1
# winRate    8.3
#
#
# 20160102_5
# hrName     창세
# hrNo       033319
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1200
# rcNo       5
# rcOrd      1
# rcP1Odd    1.8
# rcP2Odd    3.1
# rcP3Odd    26.3
# rcRank     05
# amt        544900000
# avgWinDist 1257
# condAmt    0
# fifthCnt   0
# forthCnt   1
# fstCnt     7
# hrEngNm    CHANG SE
# hrNm       창세
# outCnt     10
# quinRate   37.5
# sndCnt     2
# trdCnt     4
# winRate    29.1
#
#
# hrName     코메프리마
# hrNo       032497
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1200
# rcNo       5
# rcOrd      9
# rcP1Odd    1.8
# rcP2Odd    3.1
# rcP3Odd    26.3
# rcRank     05
# amt        25100000
# avgWinDist 1200
# condAmt    0
# fifthCnt   2
# forthCnt   0
# fstCnt     1
# hrEngNm    COME PRIMA
# hrNm       코메프리마
# outCnt     13
# quinRate   11.1
# sndCnt     1
# trdCnt     1
# winRate    5.5
#
#
# hrName     엄지강호
# hrNo       031570
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1200
# rcNo       5
# rcOrd      2
# rcP1Odd    1.8
# rcP2Odd    3.1
# rcP3Odd    26.3
# rcRank     05
# amt        142600000
# avgWinDist 1100
# condAmt    0
# fifthCnt   3
# forthCnt   3
# fstCnt     2
# hrEngNm    EOMJI GANGHO
# hrNm       엄지강호
# outCnt     16
# quinRate   26.4
# sndCnt     7
# trdCnt     3
# winRate    5.8
#
#
# hrName     희망이
# hrNo       032571
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1200
# rcNo       5
# rcOrd      13
# rcP1Odd    1.8
# rcP2Odd    3.1
# rcP3Odd    26.3
# rcRank     05
# amt        24550000
# avgWinDist 1200
# condAmt    0
# fifthCnt   0
# forthCnt   1
# fstCnt     1
# hrEngNm    HUIMANGI
# hrNm       희망이
# outCnt     14
# quinRate   11.7
# sndCnt     1
# trdCnt     0
# winRate    5.8
#
#
# hrName     달항아리
# hrNo       031778
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1200
# rcNo       5
# rcOrd      7
# rcP1Odd    1.8
# rcP2Odd    3.1
# rcP3Odd    26.3
# rcRank     05
# amt        55150000
# avgWinDist 0
# condAmt    0
# fifthCnt   1
# forthCnt   6
# fstCnt     0
# hrEngNm    DAL HANGARI
# hrNm       달항아리
# outCnt     17
# quinRate   12.9
# sndCnt     4
# trdCnt     3
# winRate    0
#
#
# hrName     은산덕해
# hrNo       032448
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1200
# rcNo       5
# rcOrd      11
# rcP1Odd    1.8
# rcP2Odd    3.1
# rcP3Odd    26.3
# rcRank     05
# amt        36950000
# avgWinDist 1200
# condAmt    0
# fifthCnt   5
# forthCnt   1
# fstCnt     1
# hrEngNm    EUNSANDEOKAE
# hrNm       은산덕해
# outCnt     7
# quinRate   12.5
# sndCnt     1
# trdCnt     1
# winRate    6.2
#
#
# hrName     키네틱
# hrNo       032289
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1200
# rcNo       5
# rcOrd      12
# rcP1Odd    1.8
# rcP2Odd    3.1
# rcP3Odd    26.3
# rcRank     05
# amt        25400000
# avgWinDist 0
# condAmt    0
# fifthCnt   3
# forthCnt   3
# fstCnt     0
# hrEngNm    KINETIC
# hrNm       키네틱
# outCnt     7
# quinRate   12.5
# sndCnt     2
# trdCnt     1
# winRate    0
#
#
# hrName     쌩쌩돌이
# hrNo       034187
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1200
# rcNo       5
# rcOrd      5
# rcP1Odd    1.8
# rcP2Odd    3.1
# rcP3Odd    26.3
# rcRank     05
# amt        186650000
# avgWinDist 1300
# condAmt    0
# fifthCnt   9
# forthCnt   5
# fstCnt     4
# hrEngNm    SSAENGSSAENG DORI
# hrNm       쌩쌩돌이
# outCnt     13
# quinRate   16.2
# sndCnt     2
# trdCnt     4
# winRate    10.8
#
#
# hrName     스피드돌풍
# hrNo       031419
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1200
# rcNo       5
# rcOrd      8
# rcP1Odd    1.8
# rcP2Odd    3.1
# rcP3Odd    26.3
# rcRank     05
# amt        16150000
# avgWinDist 1400
# condAmt    0
# fifthCnt   0
# forthCnt   1
# fstCnt     1
# hrEngNm    SPEED DOLPUNG
# hrNm       스피드돌풍
# outCnt     12
# quinRate   7.1
# sndCnt     0
# trdCnt     0
# winRate    7.1
#
#
# hrName     슈퍼엔젤
# hrNo       030469
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1200
# rcNo       5
# rcOrd      4
# rcP1Odd    1.8
# rcP2Odd    3.1
# rcP3Odd    26.3
# rcRank     05
# amt        100200000
# avgWinDist 1250
# condAmt    0
# fifthCnt   3
# forthCnt   2
# fstCnt     2
# hrEngNm    SUPER ANGEL
# hrNm       슈퍼엔젤
# outCnt     9
# quinRate   21.7
# sndCnt     3
# trdCnt     4
# winRate    8.6
#
#
# hrName     장산킹덤
# hrNo       032138
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1200
# rcNo       5
# rcOrd      10
# rcP1Odd    1.8
# rcP2Odd    3.1
# rcP3Odd    26.3
# rcRank     05
# amt        13750000
# avgWinDist 1000
# condAmt    0
# fifthCnt   0
# forthCnt   0
# fstCnt     1
# hrEngNm    JANGSANKINGDOM
# hrNm       장산킹덤
# outCnt     6
# quinRate   14.2
# sndCnt     0
# trdCnt     0
# winRate    14.2
#
#
# hrName     스타보니비
# hrNo       032215
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1200
# rcNo       5
# rcOrd      3
# rcP1Odd    1.8
# rcP2Odd    3.1
# rcP3Odd    26.3
# rcRank     05
# amt        134950000
# avgWinDist 1466
# condAmt    0
# fifthCnt   0
# forthCnt   2
# fstCnt     3
# hrEngNm    STAR BONNY BEE
# hrNm       스타보니비
# outCnt     14
# quinRate   22.2
# sndCnt     3
# trdCnt     5
# winRate    11.1
#
#
# hrName     위즈스피드
# hrNo       033153
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1200
# rcNo       5
# rcOrd      6
# rcP1Odd    1.8
# rcP2Odd    3.1
# rcP3Odd    26.3
# rcRank     05
# amt        261400000
# avgWinDist 1266
# condAmt    1100
# fifthCnt   2
# forthCnt   0
# fstCnt     6
# hrEngNm    WHIZ SPEED
# hrNm       위즈스피드
# outCnt     11
# quinRate   37.5
# sndCnt     3
# trdCnt     2
# winRate    25
#
#
# hrName     달콤한주말
# hrNo       031402
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1200
# rcNo       5
# rcOrd      14
# rcP1Odd    1.8
# rcP2Odd    3.1
# rcP3Odd    26.3
# rcRank     05
# amt        19100000
# avgWinDist 0
# condAmt    0
# fifthCnt   1
# forthCnt   0
# fstCnt     0
# hrEngNm    DALKOMHAN JUMAL
# hrNm       달콤한주말
# outCnt     15
# quinRate   10
# sndCnt     2
# trdCnt     2
# winRate    0
#
#
# 20160102_6
# hrName     프리티보이
# hrNo       033362
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1300
# rcNo       6
# rcOrd      5
# rcP1Odd    2.8
# rcP2Odd    6.3
# rcP3Odd    5.5
# rcRank     05
# amt        218000000
# avgWinDist 1233
# condAmt    0
# fifthCnt   4
# forthCnt   2
# fstCnt     3
# hrEngNm    PRETTY BOY
# hrNm       프리티보이
# outCnt     9
# quinRate   27.5
# sndCnt     5
# trdCnt     6
# winRate    10.3
#
#
# hrName     세라몬드
# hrNo       033423
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1300
# rcNo       6
# rcOrd      12
# rcP1Odd    2.8
# rcP2Odd    6.3
# rcP3Odd    5.5
# rcRank     05
# amt        43850000
# avgWinDist 1000
# condAmt    0
# fifthCnt   4
# forthCnt   1
# fstCnt     1
# hrEngNm    SERAMOND
# hrNm       세라몬드
# outCnt     14
# quinRate   4.7
# sndCnt     0
# trdCnt     1
# winRate    4.7
#
#
# hrName     정안퀸
# hrNo       031737
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1300
# rcNo       6
# rcOrd      11
# rcP1Odd    2.8
# rcP2Odd    6.3
# rcP3Odd    5.5
# rcRank     05
# amt        90300000
# avgWinDist 1233
# condAmt    0
# fifthCnt   1
# forthCnt   3
# fstCnt     3
# hrEngNm    JEONGAN QUEEN
# hrNm       정안퀸
# outCnt     14
# quinRate   12.5
# sndCnt     0
# trdCnt     3
# winRate    12.5
#
#
# hrName     빈체로에스
# hrNo       033729
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1300
# rcNo       6
# rcOrd      10
# rcP1Odd    2.8
# rcP2Odd    6.3
# rcP3Odd    5.5
# rcRank     05
# amt        37850000
# avgWinDist 1000
# condAmt    0
# fifthCnt   0
# forthCnt   1
# fstCnt     1
# hrEngNm    VINCERO S
# hrNm       빈체로에스
# outCnt     12
# quinRate   6.6
# sndCnt     0
# trdCnt     1
# winRate    6.6
#
#
# hrName     용두산
# hrNo       030580
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1300
# rcNo       6
# rcOrd      4
# rcP1Odd    2.8
# rcP2Odd    6.3
# rcP3Odd    5.5
# rcRank     05
# amt        81000000
# avgWinDist 1350
# condAmt    0
# fifthCnt   5
# forthCnt   4
# fstCnt     2
# hrEngNm    YONGDUSAN
# hrNm       용두산
# outCnt     14
# quinRate   16.6
# sndCnt     3
# trdCnt     2
# winRate    6.6
#
#
# hrName     네페르티티
# hrNo       031831
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1300
# rcNo       6
# rcOrd      8
# rcP1Odd    2.8
# rcP2Odd    6.3
# rcP3Odd    5.5
# rcRank     05
# amt        59950000
# avgWinDist 1200
# condAmt    0
# fifthCnt   3
# forthCnt   1
# fstCnt     1
# hrEngNm    NEFERTITI
# hrNm       네페르티티
# outCnt     17
# quinRate   14.8
# sndCnt     3
# trdCnt     2
# winRate    3.7
#
#
# hrName     대군마마
# hrNo       033398
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1300
# rcNo       6
# rcOrd      2
# rcP1Odd    2.8
# rcP2Odd    6.3
# rcP3Odd    5.5
# rcRank     05
# amt        144900000
# avgWinDist 1300
# condAmt    0
# fifthCnt   2
# forthCnt   1
# fstCnt     2
# hrEngNm    DAEGUN MAMA
# hrNm       대군마마
# outCnt     5
# quinRate   44.4
# sndCnt     6
# trdCnt     2
# winRate    11.1
#
#
# hrName     히든타임
# hrNo       031721
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1300
# rcNo       6
# rcOrd      13
# rcP1Odd    2.8
# rcP2Odd    6.3
# rcP3Odd    5.5
# rcRank     05
# amt        10500000
# avgWinDist 0
# condAmt    0
# fifthCnt   0
# forthCnt   0
# fstCnt     0
# hrEngNm    HIDDEN TIME
# hrNm       히든타임
# outCnt     5
# quinRate   0
# sndCnt     0
# trdCnt     3
# winRate    0
#
#
# hrName     쾌속순항
# hrNo       030389
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1300
# rcNo       6
# rcOrd      7
# rcP1Odd    2.8
# rcP2Odd    6.3
# rcP3Odd    5.5
# rcRank     05
# amt        27200000
# avgWinDist 0
# condAmt    0
# fifthCnt   1
# forthCnt   1
# fstCnt     0
# hrEngNm    KWAESOK SUNHANG
# hrNm       쾌속순항
# outCnt     25
# quinRate   6.4
# sndCnt     2
# trdCnt     2
# winRate    0
#
#
# hrName     센세이셔널
# hrNo       031452
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1300
# rcNo       6
# rcOrd      9
# rcP1Odd    2.8
# rcP2Odd    6.3
# rcP3Odd    5.5
# rcRank     05
# amt        70500000
# avgWinDist 1300
# condAmt    0
# fifthCnt   1
# forthCnt   3
# fstCnt     2
# hrEngNm    SENSATIONAL
# hrNm       센세이셔널
# outCnt     10
# quinRate   21
# sndCnt     2
# trdCnt     1
# winRate    10.5
#
#
# hrName     데블맨
# hrNo       033144
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1300
# rcNo       6
# rcOrd      14
# rcP1Odd    2.8
# rcP2Odd    6.3
# rcP3Odd    5.5
# rcRank     05
# amt        148550000
# avgWinDist 1450
# condAmt    0
# fifthCnt   5
# forthCnt   1
# fstCnt     2
# hrEngNm    DEVIL MAN
# hrNm       데블맨
# outCnt     22
# quinRate   17.5
# sndCnt     5
# trdCnt     5
# winRate    5
#
#
# hrName     선데이드리머
# hrNo       031832
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1300
# rcNo       6
# rcOrd      3
# rcP1Odd    2.8
# rcP2Odd    6.3
# rcP3Odd    5.5
# rcRank     05
# amt        38000000
# avgWinDist 1300
# condAmt    0
# fifthCnt   2
# forthCnt   1
# fstCnt     1
# hrEngNm    SUNDAY DREAMER
# hrNm       선데이드리머
# outCnt     4
# quinRate   27.2
# sndCnt     2
# trdCnt     1
# winRate    9
#
#
# hrName     선록
# hrNo       033683
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1300
# rcNo       6
# rcOrd      1
# rcP1Odd    2.8
# rcP2Odd    6.3
# rcP3Odd    5.5
# rcRank     05
# amt        350950000
# avgWinDist 1442
# condAmt    0
# fifthCnt   2
# forthCnt   1
# fstCnt     7
# hrEngNm    SUN ROK
# hrNm       선록
# outCnt     8
# quinRate   50
# sndCnt     5
# trdCnt     1
# winRate    29.1
#
#
# hrName     온더스테이지
# hrNo       033656
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1300
# rcNo       6
# rcOrd      6
# rcP1Odd    2.8
# rcP2Odd    6.3
# rcP3Odd    5.5
# rcRank     05
# amt        141600000
# avgWinDist 1275
# condAmt    0
# fifthCnt   2
# forthCnt   3
# fstCnt     4
# hrEngNm    ON THE STAGE
# hrNm       온더스테이지
# outCnt     17
# quinRate   21.4
# sndCnt     2
# trdCnt     0
# winRate    14.2
#
#
# 20160102_7
# hrName     담양젠틀맨
# hrNo       030841
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1400
# rcNo       7
# rcOrd      9
# rcP1Odd    1.3
# rcP2Odd    1.5
# rcP3Odd    3.9
# rcRank     04
# amt        70230000
# avgWinDist 1200
# condAmt    0
# fifthCnt   1
# forthCnt   2
# fstCnt     2
# hrEngNm    DAMYANG GENTLEMAN
# hrNm       담양젠틀맨
# outCnt     18
# quinRate   11.5
# sndCnt     1
# trdCnt     2
# winRate    7.6
#
#
# hrName     샤인클로버
# hrNo       031792
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1400
# rcNo       7
# rcOrd      3
# rcP1Odd    1.3
# rcP2Odd    1.5
# rcP3Odd    3.9
# rcRank     04
# amt        140650000
# avgWinDist 1000
# condAmt    0
# fifthCnt   0
# forthCnt   1
# fstCnt     1
# hrEngNm    SHINE CLOVER
# hrNm       샤인클로버
# outCnt     9
# quinRate   34.7
# sndCnt     7
# trdCnt     5
# winRate    4.3
#
#
# hrName     스피드제왕
# hrNo       031549
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1400
# rcNo       7
# rcOrd      11
# rcP1Odd    1.3
# rcP2Odd    1.5
# rcP3Odd    3.9
# rcRank     04
# amt        64870000
# avgWinDist 1250
# condAmt    0
# fifthCnt   0
# forthCnt   1
# fstCnt     2
# hrEngNm    SPEED JEWANG
# hrNm       스피드제왕
# outCnt     10
# quinRate   25
# sndCnt     2
# trdCnt     1
# winRate    12.5
#
#
# hrName     강한서울
# hrNo       025818
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1400
# rcNo       7
# rcOrd      8
# rcP1Odd    1.3
# rcP2Odd    1.5
# rcP3Odd    3.9
# rcRank     04
# amt        83346000
# avgWinDist 1200
# condAmt    0
# fifthCnt   11
# forthCnt   7
# fstCnt     1
# hrEngNm    GANGHAN SEOUL
# hrNm       강한서울
# outCnt     38
# quinRate   5
# sndCnt     2
# trdCnt     1
# winRate    1.6
#
#
# hrName     장수파티
# hrNo       027866
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1400
# rcNo       7
# rcOrd      10
# rcP1Odd    1.3
# rcP2Odd    1.5
# rcP3Odd    3.9
# rcRank     04
# amt        82166000
# avgWinDist 1250
# condAmt    40
# fifthCnt   9
# forthCnt   3
# fstCnt     2
# hrEngNm    JANGSU PARTY
# hrNm       장수파티
# outCnt     23
# quinRate   7.5
# sndCnt     1
# trdCnt     2
# winRate    5
#
#
# hrName     드림아이
# hrNo       032118
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1400
# rcNo       7
# rcOrd      14
# rcP1Odd    1.3
# rcP2Odd    1.5
# rcP3Odd    3.9
# rcRank     04
# amt        37650000
# avgWinDist 1200
# condAmt    0
# fifthCnt   3
# forthCnt   1
# fstCnt     1
# hrEngNm    DREAM EYE
# hrNm       드림아이
# outCnt     17
# quinRate   12.5
# sndCnt     2
# trdCnt     0
# winRate    4.1
#
#
# hrName     행운성
# hrNo       029748
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1400
# rcNo       7
# rcOrd      7
# rcP1Odd    1.3
# rcP2Odd    1.5
# rcP3Odd    3.9
# rcRank     04
# amt        80090000
# avgWinDist 1300
# condAmt    0
# fifthCnt   1
# forthCnt   3
# fstCnt     2
# hrEngNm    HAENGUNSEONG
# hrNm       행운성
# outCnt     15
# quinRate   12
# sndCnt     1
# trdCnt     3
# winRate    8
#
#
# hrName     라온에스프리
# hrNo       030095
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1400
# rcNo       7
# rcOrd      6
# rcP1Odd    1.3
# rcP2Odd    1.5
# rcP3Odd    3.9
# rcRank     04
# amt        102590000
# avgWinDist 1200
# condAmt    0
# fifthCnt   6
# forthCnt   7
# fstCnt     2
# hrEngNm    RAON ESPRIT
# hrNm       라온에스프리
# outCnt     14
# quinRate   12.1
# sndCnt     2
# trdCnt     2
# winRate    6
#
#
# hrName     좋은데이
# hrNo       030657
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1400
# rcNo       7
# rcOrd      4
# rcP1Odd    1.3
# rcP2Odd    1.5
# rcP3Odd    3.9
# rcRank     04
# amt        89750000
# avgWinDist 0
# condAmt    0
# fifthCnt   1
# forthCnt   8
# fstCnt     0
# hrEngNm    JOEUN DAY
# hrNm       좋은데이
# outCnt     17
# quinRate   14.2
# sndCnt     5
# trdCnt     4
# winRate    0
#
#
# hrName     맥시멈스피드
# hrNo       026543
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1400
# rcNo       7
# rcOrd      13
# rcP1Odd    1.3
# rcP2Odd    1.5
# rcP3Odd    3.9
# rcRank     04
# amt        81457000
# avgWinDist 1300
# condAmt    0
# fifthCnt   3
# forthCnt   3
# fstCnt     1
# hrEngNm    MAXIMUM SPEED
# hrNm       맥시멈스피드
# outCnt     31
# quinRate   11.3
# sndCnt     4
# trdCnt     2
# winRate    2.2
#
#
# hrName     키스미
# hrNo       027947
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1400
# rcNo       7
# rcOrd      12
# rcP1Odd    1.3
# rcP2Odd    1.5
# rcP3Odd    3.9
# rcRank     04
# amt        36640000
# avgWinDist 1300
# condAmt    0
# fifthCnt   3
# forthCnt   0
# fstCnt     1
# hrEngNm    KISS ME
# hrNm       키스미
# outCnt     23
# quinRate   10.3
# sndCnt     2
# trdCnt     0
# winRate    3.4
#
#
# hrName     뷰티어스니스
# hrNo       022438
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1400
# rcNo       7
# rcOrd      5
# rcP1Odd    1.3
# rcP2Odd    1.5
# rcP3Odd    3.9
# rcRank     04
# amt        115229000
# avgWinDist 1300
# condAmt    0
# fifthCnt   10
# forthCnt   4
# fstCnt     2
# hrEngNm    BEAUTEOUSNESS
# hrNm       뷰티어스니스
# outCnt     63
# quinRate   4.7
# sndCnt     2
# trdCnt     3
# winRate    2.3
#
#
# hrName     천지스톰
# hrNo       034254
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1400
# rcNo       7
# rcOrd      1
# rcP1Odd    1.3
# rcP2Odd    1.5
# rcP3Odd    3.9
# rcRank     04
# amt        970050000
# avgWinDist 1522
# condAmt    720
# fifthCnt   0
# forthCnt   0
# fstCnt     9
# hrEngNm    CHEONJI STORM
# hrNm       천지스톰
# outCnt     11
# quinRate   48.1
# sndCnt     4
# trdCnt     3
# winRate    33.3
#
#
# hrName     황룡비상
# hrNo       031331
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1400
# rcNo       7
# rcOrd      2
# rcP1Odd    1.3
# rcP2Odd    1.5
# rcP3Odd    3.9
# rcRank     04
# amt        140800000
# avgWinDist 1433
# condAmt    0
# fifthCnt   3
# forthCnt   4
# fstCnt     3
# hrEngNm    HWANGNYONGBISANG
# hrNm       황룡비상
# outCnt     5
# quinRate   27.2
# sndCnt     3
# trdCnt     4
# winRate    13.6
#
#
# 20160102_8
# hrName     아이디이천
# hrNo       030973
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1800
# rcNo       8
# rcOrd      6
# rcP1Odd    2.5
# rcP2Odd    1.5
# rcP3Odd    2.9
# rcRank     03
# amt        104626000
# avgWinDist 1400
# condAmt    0
# fifthCnt   4
# forthCnt   3
# fstCnt     2
# hrEngNm    ID ICHEON
# hrNm       아이디이천
# outCnt     13
# quinRate   13
# sndCnt     1
# trdCnt     0
# winRate    8.6
#
#
# hrName     굿타임조니
# hrNo       034689
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1800
# rcNo       8
# rcOrd      3
# rcP1Odd    2.5
# rcP2Odd    1.5
# rcP3Odd    2.9
# rcRank     03
# amt        67820000
# avgWinDist 1000
# condAmt    0
# fifthCnt   2
# forthCnt   0
# fstCnt     1
# hrEngNm    GOOD TIME JOHNNY
# hrNm       굿타임조니
# outCnt     4
# quinRate   30
# sndCnt     2
# trdCnt     1
# winRate    10
#
#
# hrName     바빌론왕자
# hrNo       034482
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1800
# rcNo       8
# rcOrd      7
# rcP1Odd    2.5
# rcP2Odd    1.5
# rcP3Odd    2.9
# rcRank     03
# amt        89600000
# avgWinDist 0
# condAmt    0
# fifthCnt   5
# forthCnt   2
# fstCnt     0
# hrEngNm    BABYLON WANGJA
# hrNm       바빌론왕자
# outCnt     15
# quinRate   6.8
# sndCnt     2
# trdCnt     5
# winRate    0
#
#
# hrName     레디칸
# hrNo       034585
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1800
# rcNo       8
# rcOrd      1
# rcP1Odd    2.5
# rcP2Odd    1.5
# rcP3Odd    2.9
# rcRank     03
# amt        244700000
# avgWinDist 1700
# condAmt    70
# fifthCnt   3
# forthCnt   5
# fstCnt     4
# hrEngNm    READY KHAN
# hrNm       레디칸
# outCnt     18
# quinRate   14.7
# sndCnt     1
# trdCnt     3
# winRate    11.7
#
#
# hrName     행복의나라
# hrNo       033045
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1800
# rcNo       8
# rcOrd      2
# rcP1Odd    2.5
# rcP2Odd    1.5
# rcP3Odd    2.9
# rcRank     03
# amt        111050000
# avgWinDist 1400
# condAmt    0
# fifthCnt   2
# forthCnt   1
# fstCnt     1
# hrEngNm    HAENGBOGUI NARA
# hrNm       행복의나라
# outCnt     6
# quinRate   23.5
# sndCnt     3
# trdCnt     4
# winRate    5.8
#
#
# hrName     무미아준
# hrNo       032934
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1800
# rcNo       8
# rcOrd      9
# rcP1Odd    2.5
# rcP2Odd    1.5
# rcP3Odd    2.9
# rcRank     03
# amt        57200000
# avgWinDist 0
# condAmt    0
# fifthCnt   2
# forthCnt   2
# fstCnt     0
# hrEngNm    MUMIA JUN
# hrNm       무미아준
# outCnt     12
# quinRate   15
# sndCnt     3
# trdCnt     1
# winRate    0
#
#
# hrName     장산태양
# hrNo       034564
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1800
# rcNo       8
# rcOrd      4
# rcP1Odd    2.5
# rcP2Odd    1.5
# rcP3Odd    2.9
# rcRank     03
# amt        90820000
# avgWinDist 1200
# condAmt    0
# fifthCnt   5
# forthCnt   4
# fstCnt     1
# hrEngNm    JANGSAN TAEYANG
# hrNm       장산태양
# outCnt     11
# quinRate   13
# sndCnt     2
# trdCnt     0
# winRate    4.3
#
#
# hrName     황금가속
# hrNo       032692
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1800
# rcNo       8
# rcOrd      5
# rcP1Odd    2.5
# rcP2Odd    1.5
# rcP3Odd    2.9
# rcRank     03
# amt        106390000
# avgWinDist 0
# condAmt    0
# fifthCnt   7
# forthCnt   2
# fstCnt     0
# hrEngNm    HWANGGEUM GASOK
# hrNm       황금가속
# outCnt     23
# quinRate   7.5
# sndCnt     3
# trdCnt     5
# winRate    0
#
#
# hrName     갈라캣
# hrNo       032737
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1800
# rcNo       8
# rcOrd      8
# rcP1Odd    2.5
# rcP2Odd    1.5
# rcP3Odd    2.9
# rcRank     03
# amt        185360000
# avgWinDist 1200
# condAmt    0
# fifthCnt   7
# forthCnt   7
# fstCnt     1
# hrEngNm    GALACAT
# hrNm       갈라캣
# outCnt     29
# quinRate   9.4
# sndCnt     4
# trdCnt     5
# winRate    1.8
#
#
# 20160102_9
# hrName     로열스타
# hrNo       031736
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1400
# rcNo       9
# rcOrd      4
# rcP1Odd    1.6
# rcP2Odd    5.5
# rcP3Odd    75.5
# rcRank     02
# amt        228250000
# avgWinDist 1116
# condAmt    50
# fifthCnt   2
# forthCnt   1
# fstCnt     6
# hrEngNm    ROYAL STAR
# hrNm       로열스타
# outCnt     6
# quinRate   47
# sndCnt     2
# trdCnt     0
# winRate    35.2
#
#
# hrName     터보제트
# hrNo       030053
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1400
# rcNo       9
# rcOrd      7
# rcP1Odd    1.6
# rcP2Odd    5.5
# rcP3Odd    75.5
# rcRank     02
# amt        193240000
# avgWinDist 1400
# condAmt    0
# fifthCnt   1
# forthCnt   2
# fstCnt     4
# hrEngNm    TURBO JET
# hrNm       터보제트
# outCnt     5
# quinRate   47
# sndCnt     4
# trdCnt     1
# winRate    23.5
#
#
# hrName     불굴의투사
# hrNo       032953
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1400
# rcNo       9
# rcOrd      10
# rcP1Odd    1.6
# rcP2Odd    5.5
# rcP3Odd    75.5
# rcRank     02
# amt        141810000
# avgWinDist 1450
# condAmt    0
# fifthCnt   0
# forthCnt   1
# fstCnt     2
# hrEngNm    BULGURUI TUSA
# hrNm       불굴의투사
# outCnt     17
# quinRate   16
# sndCnt     2
# trdCnt     3
# winRate    8
#
#
# hrName     베니윈
# hrNo       028758
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1400
# rcNo       9
# rcOrd      2
# rcP1Odd    1.6
# rcP2Odd    5.5
# rcP3Odd    75.5
# rcRank     02
# amt        299594000
# avgWinDist 1675
# condAmt    0
# fifthCnt   6
# forthCnt   6
# fstCnt     4
# hrEngNm    VENI WIN
# hrNm       베니윈
# outCnt     19
# quinRate   24.4
# sndCnt     7
# trdCnt     3
# winRate    8.8
#
#
# hrName     소천하
# hrNo       027497
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1400
# rcNo       9
# rcOrd      3
# rcP1Odd    1.6
# rcP2Odd    5.5
# rcP3Odd    75.5
# rcRank     02
# amt        337208000
# avgWinDist 1300
# condAmt    0
# fifthCnt   12
# forthCnt   11
# fstCnt     2
# hrEngNm    SOCHEONHA
# hrNm       소천하
# outCnt     31
# quinRate   11.5
# sndCnt     6
# trdCnt     7
# winRate    2.8
#
#
# hrName     강호시대
# hrNo       029297
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1400
# rcNo       9
# rcOrd      11
# rcP1Odd    1.6
# rcP2Odd    5.5
# rcP3Odd    75.5
# rcRank     02
# amt        191593000
# avgWinDist 1600
# condAmt    0
# fifthCnt   4
# forthCnt   3
# fstCnt     2
# hrEngNm    GANGHO SIDAE
# hrNm       강호시대
# outCnt     30
# quinRate   10.4
# sndCnt     3
# trdCnt     6
# winRate    4.1
#
#
# hrName     드림포트
# hrNo       030502
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1400
# rcNo       9
# rcOrd      9
# rcP1Odd    1.6
# rcP2Odd    5.5
# rcP3Odd    75.5
# rcRank     02
# amt        168530000
# avgWinDist 1175
# condAmt    0
# fifthCnt   5
# forthCnt   2
# fstCnt     4
# hrEngNm    DREAM FT.
# hrNm       드림포트
# outCnt     15
# quinRate   23.3
# sndCnt     3
# trdCnt     1
# winRate    13.3
#
#
# hrName     스톰히트
# hrNo       031091
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1400
# rcNo       9
# rcOrd      8
# rcP1Odd    1.6
# rcP2Odd    5.5
# rcP3Odd    75.5
# rcRank     02
# amt        127866000
# avgWinDist 1300
# condAmt    0
# fifthCnt   1
# forthCnt   4
# fstCnt     1
# hrEngNm    STORM HIT
# hrNm       스톰히트
# outCnt     25
# quinRate   10.5
# sndCnt     3
# trdCnt     4
# winRate    2.6
#
#
# hrName     스토리텔링
# hrNo       034678
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1400
# rcNo       9
# rcOrd      6
# rcP1Odd    1.6
# rcP2Odd    5.5
# rcP3Odd    75.5
# rcRank     02
# amt        122700000
# avgWinDist 1200
# condAmt    0
# fifthCnt   6
# forthCnt   1
# fstCnt     1
# hrEngNm    STORYTELLING
# hrNm       스토리텔링
# outCnt     9
# quinRate   22.7
# sndCnt     4
# trdCnt     1
# winRate    4.5
#
#
# hrName     금포여장군
# hrNo       032955
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1400
# rcNo       9
# rcOrd      5
# rcP1Odd    1.6
# rcP2Odd    5.5
# rcP3Odd    75.5
# rcRank     02
# amt        136325000
# avgWinDist 1400
# condAmt    1970
# fifthCnt   3
# forthCnt   4
# fstCnt     2
# hrEngNm    GUMPO YEOJANGGUN
# hrNm       금포여장군
# outCnt     19
# quinRate   12.1
# sndCnt     2
# trdCnt     3
# winRate    6
#
#
# hrName     샌드위즈
# hrNo       032670
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1400
# rcNo       9
# rcOrd      12
# rcP1Odd    1.6
# rcP2Odd    5.5
# rcP3Odd    75.5
# rcRank     02
# amt        108070000
# avgWinDist 1200
# condAmt    0
# fifthCnt   2
# forthCnt   3
# fstCnt     2
# hrEngNm    SAND WHIZZ
# hrNm       샌드위즈
# outCnt     19
# quinRate   10.3
# sndCnt     1
# trdCnt     2
# winRate    6.8
#
#
# hrName     선버스터
# hrNo       032297
# meet       서울
# noracefl   정상
# rcDate     20160102
# rcDist     1400
# rcNo       9
# rcOrd      1
# rcP1Odd    1.6
# rcP2Odd    5.5
# rcP3Odd    75.5
# rcRank     02
# amt        354300000
# avgWinDist 1333
# condAmt    0
# fifthCnt   3
# forthCnt   2
# fstCnt     6
# hrEngNm    SUN BURSTER
# hrNm       선버스터
# outCnt     5
# quinRate   50
# sndCnt     6
# trdCnt     2
# winRate    25
#
#
# 20160103_4
# hrName     불꽃왕자
# hrNo       031845
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1400
# rcNo       4
# rcOrd      3
# rcP1Odd    5
# rcP2Odd    1.6
# rcP3Odd    8.5
# rcRank     05
# amt        192450000
# avgWinDist 1350
# condAmt    0
# fifthCnt   2
# forthCnt   4
# fstCnt     4
# hrEngNm    BULKKOCHWANGJA
# hrNm       불꽃왕자
# outCnt     10
# quinRate   20.6
# sndCnt     2
# trdCnt     7
# winRate    13.7
#
#
# hrName     초원파티
# hrNo       030484
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1400
# rcNo       4
# rcOrd      7
# rcP1Odd    5
# rcP2Odd    1.6
# rcP3Odd    8.5
# rcRank     05
# amt        25080000
# avgWinDist 0
# condAmt    0
# fifthCnt   2
# forthCnt   2
# fstCnt     0
# hrEngNm    CHOWON PARTY
# hrNm       초원파티
# outCnt     25
# quinRate   3
# sndCnt     1
# trdCnt     3
# winRate    0
#
#
# hrName     하이유레카
# hrNo       034179
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1400
# rcNo       4
# rcOrd      14
# rcP1Odd    5
# rcP2Odd    1.6
# rcP3Odd    8.5
# rcRank     05
# amt        102800000
# avgWinDist 1000
# condAmt    0
# fifthCnt   5
# forthCnt   4
# fstCnt     2
# hrEngNm    HI EUREKA
# hrNm       하이유레카
# outCnt     13
# quinRate   12.5
# sndCnt     2
# trdCnt     6
# winRate    6.2
#
#
# hrName     미스터탱크
# hrNo       031697
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1400
# rcNo       4
# rcOrd      5
# rcP1Odd    5
# rcP2Odd    1.6
# rcP3Odd    8.5
# rcRank     05
# amt        75150000
# avgWinDist 1400
# condAmt    0
# fifthCnt   7
# forthCnt   4
# fstCnt     1
# hrEngNm    MR. TANK
# hrNm       미스터탱크
# outCnt     15
# quinRate   9
# sndCnt     2
# trdCnt     4
# winRate    3
#
#
# hrName     청춘열차
# hrNo       032248
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1400
# rcNo       4
# rcOrd      2
# rcP1Odd    5
# rcP2Odd    1.6
# rcP3Odd    8.5
# rcRank     05
# amt        128800000
# avgWinDist 1200
# condAmt    370
# fifthCnt   3
# forthCnt   7
# fstCnt     2
# hrEngNm    CHEONGCHUN YEOLCHA
# hrNm       청춘열차
# outCnt     19
# quinRate   21
# sndCnt     6
# trdCnt     1
# winRate    5.2
#
#
# hrName     도솔봉
# hrNo       030797
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1400
# rcNo       4
# rcOrd      11
# rcP1Odd    5
# rcP2Odd    1.6
# rcP3Odd    8.5
# rcRank     05
# amt        25800000
# avgWinDist 1200
# condAmt    0
# fifthCnt   1
# forthCnt   1
# fstCnt     1
# hrEngNm    DOSOLBONG
# hrNm       도솔봉
# outCnt     17
# quinRate   9.5
# sndCnt     1
# trdCnt     0
# winRate    4.7
#
#
# hrName     당찬비상
# hrNo       032407
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1400
# rcNo       4
# rcOrd      12
# rcP1Odd    5
# rcP2Odd    1.6
# rcP3Odd    8.5
# rcRank     05
# amt        65400000
# avgWinDist 1300
# condAmt    0
# fifthCnt   6
# forthCnt   1
# fstCnt     1
# hrEngNm    DANGCHANBISANG
# hrNm       당찬비상
# outCnt     10
# quinRate   21.7
# sndCnt     4
# trdCnt     1
# winRate    4.3
#
#
# hrName     루나챔프
# hrNo       031564
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1400
# rcNo       4
# rcOrd      10
# rcP1Odd    5
# rcP2Odd    1.6
# rcP3Odd    8.5
# rcRank     05
# amt        44600000
# avgWinDist 0
# condAmt    0
# fifthCnt   4
# forthCnt   4
# fstCnt     0
# hrEngNm    LUNA CHAMP
# hrNm       루나챔프
# outCnt     28
# quinRate   7.3
# sndCnt     3
# trdCnt     2
# winRate    0
#
#
# hrName     오카방고
# hrNo       031640
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1400
# rcNo       4
# rcOrd      13
# rcP1Odd    5
# rcP2Odd    1.6
# rcP3Odd    8.5
# rcRank     05
# amt        29400000
# avgWinDist 0
# condAmt    0
# fifthCnt   5
# forthCnt   2
# fstCnt     0
# hrEngNm    OKAVANGO
# hrNm       오카방고
# outCnt     9
# quinRate   10.5
# sndCnt     2
# trdCnt     1
# winRate    0
#
#
# hrName     지상거탑
# hrNo       032492
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1400
# rcNo       4
# rcOrd      8
# rcP1Odd    5
# rcP2Odd    1.6
# rcP3Odd    8.5
# rcRank     05
# amt        133900000
# avgWinDist 1700
# condAmt    0
# fifthCnt   4
# forthCnt   4
# fstCnt     1
# hrEngNm    JISANGGEOTAP
# hrNm       지상거탑
# outCnt     20
# quinRate   22.5
# sndCnt     8
# trdCnt     3
# winRate    2.5
#
#
# hrName     친친짠
# hrNo       033240
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1400
# rcNo       4
# rcOrd      1
# rcP1Odd    5
# rcP2Odd    1.6
# rcP3Odd    8.5
# rcRank     05
# amt        205750000
# avgWinDist 1160
# condAmt    0
# fifthCnt   2
# forthCnt   2
# fstCnt     5
# hrEngNm    CIN CIN JJAN
# hrNm       친친짠
# outCnt     14
# quinRate   25.9
# sndCnt     2
# trdCnt     2
# winRate    18.5
#
#
# hrName     돌체비타
# hrNo       030245
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1400
# rcNo       4
# rcOrd      9
# rcP1Odd    5
# rcP2Odd    1.6
# rcP3Odd    8.5
# rcRank     05
# amt        45120000
# avgWinDist 0
# condAmt    0
# fifthCnt   4
# forthCnt   5
# fstCnt     0
# hrEngNm    DOLCE VITA
# hrNm       돌체비타
# outCnt     26
# quinRate   5
# sndCnt     2
# trdCnt     3
# winRate    0
#
#
# hrName     위즈런
# hrNo       033238
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1400
# rcNo       4
# rcOrd      6
# rcP1Odd    5
# rcP2Odd    1.6
# rcP3Odd    8.5
# rcRank     05
# amt        94750000
# avgWinDist 1333
# condAmt    0
# fifthCnt   1
# forthCnt   1
# fstCnt     3
# hrEngNm    WHIZ RUN
# hrNm       위즈런
# outCnt     5
# quinRate   41.6
# sndCnt     2
# trdCnt     0
# winRate    25
#
#
# hrName     해피볼
# hrNo       030109
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1400
# rcNo       4
# rcOrd      4
# rcP1Odd    5
# rcP2Odd    1.6
# rcP3Odd    8.5
# rcRank     05
# amt        96600000
# avgWinDist 1200
# condAmt    0
# fifthCnt   2
# forthCnt   4
# fstCnt     2
# hrEngNm    HAPPY BALL
# hrNm       해피볼
# outCnt     12
# quinRate   23
# sndCnt     4
# trdCnt     2
# winRate    7.6
#
#
# 20160103_5
# hrName     시티즌엠
# hrNo       036526
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       5
# rcOrd      5
# rcP1Odd    25
# rcP2Odd    3.1
# rcP3Odd    65.5
# rcRank     04
# amt        9000000
# avgWinDist 0
# condAmt    30
# fifthCnt   4
# forthCnt   0
# fstCnt     0
# hrEngNm    CITIZEN M
# hrNm       시티즌엠
# outCnt     16
# quinRate   0
# sndCnt     0
# trdCnt     0
# winRate    0
#
#
# hrName     렛츠고런
# hrNo       034443
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       5
# rcOrd      8
# rcP1Odd    25
# rcP2Odd    3.1
# rcP3Odd    65.5
# rcRank     04
# amt        58100000
# avgWinDist 0
# condAmt    0
# fifthCnt   3
# forthCnt   7
# fstCnt     0
# hrEngNm    LET'S GO RUN
# hrNm       렛츠고런
# outCnt     15
# quinRate   0
# sndCnt     0
# trdCnt     4
# winRate    0
#
#
# hrName     와인메이커
# hrNo       034834
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       5
# rcOrd      4
# rcP1Odd    25
# rcP2Odd    3.1
# rcP3Odd    65.5
# rcRank     04
# amt        42500000
# avgWinDist 0
# condAmt    0
# fifthCnt   0
# forthCnt   1
# fstCnt     0
# hrEngNm    WINE MAKER
# hrNm       와인메이커
# outCnt     15
# quinRate   0
# sndCnt     0
# trdCnt     5
# winRate    0
#
#
# hrName     매직행복
# hrNo       034749
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       5
# rcOrd      12
# rcP1Odd    25
# rcP2Odd    3.1
# rcP3Odd    65.5
# rcRank     04
# amt        0
# avgWinDist 0
# condAmt    0
# fifthCnt   0
# forthCnt   0
# fstCnt     0
# hrEngNm    MAGIC HAENGBOK
# hrNm       매직행복
# outCnt     4
# quinRate   0
# sndCnt     0
# trdCnt     0
# winRate    0
#
#
# hrName     보은용사
# hrNo       034659
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       5
# rcOrd      10
# rcP1Odd    25
# rcP2Odd    3.1
# rcP3Odd    65.5
# rcRank     04
# amt        129850000
# avgWinDist 1300
# condAmt    0
# fifthCnt   0
# forthCnt   0
# fstCnt     2
# hrEngNm    BOEUN YONGSA
# hrNm       보은용사
# outCnt     9
# quinRate   25
# sndCnt     2
# trdCnt     3
# winRate    12.5
#
#
# hrName     스카이제왕
# hrNo       034881
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       5
# rcOrd      3
# rcP1Odd    25
# rcP2Odd    3.1
# rcP3Odd    65.5
# rcRank     04
# amt        85150000
# avgWinDist 1000
# condAmt    0
# fifthCnt   1
# forthCnt   2
# fstCnt     1
# hrEngNm    SKY JEWANG
# hrNm       스카이제왕
# outCnt     10
# quinRate   11.1
# sndCnt     1
# trdCnt     3
# winRate    5.5
#
#
# hrName     승자예찬
# hrNo       034802
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       5
# rcOrd      95
# rcP1Odd    25
# rcP2Odd    3.1
# rcP3Odd    65.5
# rcRank     04
# amt        0
# avgWinDist 0
# condAmt    0
# fifthCnt   0
# forthCnt   0
# fstCnt     0
# hrEngNm    SEUNGJA YECHAN
# hrNm       승자예찬
# outCnt     5
# quinRate   0
# sndCnt     0
# trdCnt     0
# winRate    0
#
#
# hrName     스노우카리스마
# hrNo       036458
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       5
# rcOrd      1
# rcP1Odd    25
# rcP2Odd    3.1
# rcP3Odd    65.5
# rcRank     04
# amt        175900000
# avgWinDist 1300
# condAmt    0
# fifthCnt   0
# forthCnt   2
# fstCnt     2
# hrEngNm    SNOW CHARISMA
# hrNm       스노우카리스마
# outCnt     16
# quinRate   22.2
# sndCnt     4
# trdCnt     3
# winRate    7.4
#
#
# hrName     뮤직보이
# hrNo       032674
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       5
# rcOrd      13
# rcP1Odd    25
# rcP2Odd    3.1
# rcP3Odd    65.5
# rcRank     04
# amt        14000000
# avgWinDist 0
# condAmt    0
# fifthCnt   0
# forthCnt   0
# fstCnt     0
# hrEngNm    MUSIC BOY
# hrNm       뮤직보이
# outCnt     6
# quinRate   0
# sndCnt     0
# trdCnt     2
# winRate    0
#
#
# hrName     마이티힘
# hrNo       032932
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       5
# rcOrd      7
# rcP1Odd    25
# rcP2Odd    3.1
# rcP3Odd    65.5
# rcRank     04
# amt        22500000
# avgWinDist 0
# condAmt    0
# fifthCnt   3
# forthCnt   0
# fstCnt     0
# hrEngNm    MIGHTY HIM
# hrNm       마이티힘
# outCnt     12
# quinRate   0
# sndCnt     0
# trdCnt     2
# winRate    0
#
#
# hrName     토탈워커
# hrNo       036500
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       5
# rcOrd      9
# rcP1Odd    25
# rcP2Odd    3.1
# rcP3Odd    65.5
# rcRank     04
# amt        152350000
# avgWinDist 1700
# condAmt    0
# fifthCnt   6
# forthCnt   4
# fstCnt     1
# hrEngNm    TOTAL WALKER
# hrNm       토탈워커
# outCnt     20
# quinRate   10.2
# sndCnt     3
# trdCnt     5
# winRate    2.5
#
#
# hrName     블랙시가
# hrNo       034508
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       5
# rcOrd      6
# rcP1Odd    25
# rcP2Odd    3.1
# rcP3Odd    65.5
# rcRank     04
# amt        26900000
# avgWinDist 0
# condAmt    0
# fifthCnt   3
# forthCnt   2
# fstCnt     0
# hrEngNm    BLACK CIGAR
# hrNm       블랙시가
# outCnt     11
# quinRate   0
# sndCnt     0
# trdCnt     2
# winRate    0
#
#
# hrName     별두
# hrNo       034693
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       5
# rcOrd      2
# rcP1Odd    25
# rcP2Odd    3.1
# rcP3Odd    65.5
# rcRank     04
# amt        55250000
# avgWinDist 1400
# condAmt    0
# fifthCnt   3
# forthCnt   1
# fstCnt     1
# hrEngNm    BYEOLDU
# hrNm       별두
# outCnt     11
# quinRate   11.7
# sndCnt     1
# trdCnt     0
# winRate    5.8
#
#
# hrName     강남스타
# hrNo       032764
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       5
# rcOrd      11
# rcP1Odd    25
# rcP2Odd    3.1
# rcP3Odd    65.5
# rcRank     04
# amt        60700000
# avgWinDist 0
# condAmt    0
# fifthCnt   9
# forthCnt   6
# fstCnt     0
# hrEngNm    GANGNAM STAR
# hrNm       강남스타
# outCnt     19
# quinRate   0
# sndCnt     0
# trdCnt     3
# winRate    0
#
#
# 20160103_6
# hrName     프로포즈
# hrNo       032616
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       6
# rcOrd      1
# rcP1Odd    7.3
# rcP2Odd    1.9
# rcP3Odd    24.8
# rcRank     04
# amt        181200000
# avgWinDist 1300
# condAmt    0
# fifthCnt   3
# forthCnt   2
# fstCnt     4
# hrEngNm    PROPOSE
# hrNm       프로포즈
# outCnt     6
# quinRate   40
# sndCnt     4
# trdCnt     1
# winRate    20
#
#
# hrName     토호
# hrNo       031790
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       6
# rcOrd      6
# rcP1Odd    7.3
# rcP2Odd    1.9
# rcP3Odd    24.8
# rcRank     04
# amt        60820000
# avgWinDist 1000
# condAmt    0
# fifthCnt   1
# forthCnt   2
# fstCnt     2
# hrEngNm    TOHO
# hrNm       토호
# outCnt     9
# quinRate   18.7
# sndCnt     1
# trdCnt     1
# winRate    12.5
#
#
# hrName     대돌풍
# hrNo       030408
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       6
# rcOrd      10
# rcP1Odd    7.3
# rcP2Odd    1.9
# rcP3Odd    24.8
# rcRank     04
# amt        189690000
# avgWinDist 1400
# condAmt    0
# fifthCnt   6
# forthCnt   6
# fstCnt     2
# hrEngNm    DAEDOLPUNG
# hrNm       대돌풍
# outCnt     13
# quinRate   21.6
# sndCnt     6
# trdCnt     4
# winRate    5.4
#
#
# hrName     마리아고
# hrNo       030488
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       6
# rcOrd      7
# rcP1Odd    7.3
# rcP2Odd    1.9
# rcP3Odd    24.8
# rcRank     04
# amt        87430000
# avgWinDist 1200
# condAmt    0
# fifthCnt   4
# forthCnt   2
# fstCnt     1
# hrEngNm    MARIA GO
# hrNm       마리아고
# outCnt     14
# quinRate   14.2
# sndCnt     3
# trdCnt     4
# winRate    3.5
#
#
# hrName     볼포니스윙
# hrNo       028661
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       6
# rcOrd      5
# rcP1Odd    7.3
# rcP2Odd    1.9
# rcP3Odd    24.8
# rcRank     04
# amt        72490000
# avgWinDist 1200
# condAmt    0
# fifthCnt   6
# forthCnt   4
# fstCnt     2
# hrEngNm    VOLPONI SWING
# hrNm       볼포니스윙
# outCnt     32
# quinRate   4.3
# sndCnt     0
# trdCnt     2
# winRate    4.3
#
#
# hrName     옥천지
# hrNo       030387
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       6
# rcOrd      12
# rcP1Odd    7.3
# rcP2Odd    1.9
# rcP3Odd    24.8
# rcRank     04
# amt        58310000
# avgWinDist 0
# condAmt    0
# fifthCnt   2
# forthCnt   5
# fstCnt     0
# hrEngNm    OKCHEONJI
# hrNm       옥천지
# outCnt     22
# quinRate   11.4
# sndCnt     4
# trdCnt     2
# winRate    0
#
#
# hrName     비마
# hrNo       030686
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       6
# rcOrd      8
# rcP1Odd    7.3
# rcP2Odd    1.9
# rcP3Odd    24.8
# rcRank     04
# amt        123520000
# avgWinDist 1266
# condAmt    0
# fifthCnt   5
# forthCnt   4
# fstCnt     3
# hrEngNm    BIMA
# hrNm       비마
# outCnt     9
# quinRate   20.8
# sndCnt     2
# trdCnt     1
# winRate    12.5
#
#
# hrName     더블제이
# hrNo       030310
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       6
# rcOrd      9
# rcP1Odd    7.3
# rcP2Odd    1.9
# rcP3Odd    24.8
# rcRank     04
# amt        122250000
# avgWinDist 1000
# condAmt    0
# fifthCnt   2
# forthCnt   4
# fstCnt     1
# hrEngNm    DOUBLE J
# hrNm       더블제이
# outCnt     21
# quinRate   15.7
# sndCnt     5
# trdCnt     5
# winRate    2.6
#
#
# hrName     번개파워
# hrNo       030420
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       6
# rcOrd      13
# rcP1Odd    7.3
# rcP2Odd    1.9
# rcP3Odd    24.8
# rcRank     04
# amt        92790000
# avgWinDist 1250
# condAmt    0
# fifthCnt   2
# forthCnt   5
# fstCnt     2
# hrEngNm    BEONGAE POWER
# hrNm       번개파워
# outCnt     30
# quinRate   9.3
# sndCnt     2
# trdCnt     2
# winRate    4.6
#
#
# hrName     인수재
# hrNo       032479
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       6
# rcOrd      3
# rcP1Odd    7.3
# rcP2Odd    1.9
# rcP3Odd    24.8
# rcRank     04
# amt        176950000
# avgWinDist 1233
# condAmt    0
# fifthCnt   3
# forthCnt   3
# fstCnt     3
# hrEngNm    INSUJAE
# hrNm       인수재
# outCnt     16
# quinRate   17.1
# sndCnt     3
# trdCnt     7
# winRate    8.5
#
#
# hrName     발원지
# hrNo       029958
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       6
# rcOrd      4
# rcP1Odd    7.3
# rcP2Odd    1.9
# rcP3Odd    24.8
# rcRank     04
# amt        81250000
# avgWinDist 1000
# condAmt    0
# fifthCnt   4
# forthCnt   2
# fstCnt     1
# hrEngNm    BARWONJI
# hrNm       발원지
# outCnt     14
# quinRate   11.1
# sndCnt     2
# trdCnt     4
# winRate    3.7
#
#
# hrName     퍼펙트비카
# hrNo       031554
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       6
# rcOrd      11
# rcP1Odd    7.3
# rcP2Odd    1.9
# rcP3Odd    24.8
# rcRank     04
# amt        107900000
# avgWinDist 1200
# condAmt    0
# fifthCnt   0
# forthCnt   0
# fstCnt     3
# hrEngNm    PERFECT VICAR
# hrNm       퍼펙트비카
# outCnt     6
# quinRate   38.4
# sndCnt     2
# trdCnt     2
# winRate    23
#
#
# hrName     비호바람
# hrNo       031687
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1200
# rcNo       6
# rcOrd      2
# rcP1Odd    7.3
# rcP2Odd    1.9
# rcP3Odd    24.8
# rcRank     04
# amt        110050000
# avgWinDist 1233
# condAmt    0
# fifthCnt   1
# forthCnt   2
# fstCnt     3
# hrEngNm    BIHOBARAM
# hrNm       비호바람
# outCnt     13
# quinRate   26
# sndCnt     3
# trdCnt     1
# winRate    13
#
#
# 20160103_7
# hrName     스트롱샤인
# hrNo       030761
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1700
# rcNo       7
# rcOrd      6
# rcP1Odd    20.8
# rcP2Odd    3.1
# rcP3Odd    171.4
# rcRank     05
# amt        195700000
# avgWinDist 1566
# condAmt    0
# fifthCnt   7
# forthCnt   13
# fstCnt     3
# hrEngNm    STRONG SHINE
# hrNm       스트롱샤인
# outCnt     42
# quinRate   6.5
# sndCnt     2
# trdCnt     9
# winRate    3.9
#
#
# hrName     스페셜로드힐
# hrNo       031427
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1700
# rcNo       7
# rcOrd      4
# rcP1Odd    20.8
# rcP2Odd    3.1
# rcP3Odd    171.4
# rcRank     05
# amt        175400000
# avgWinDist 1500
# condAmt    0
# fifthCnt   2
# forthCnt   5
# fstCnt     2
# hrEngNm    SPECIAL ROAD HILL
# hrNm       스페셜로드힐
# outCnt     14
# quinRate   29.4
# sndCnt     8
# trdCnt     3
# winRate    5.8
#
#
# hrName     온에어
# hrNo       031492
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1700
# rcNo       7
# rcOrd      8
# rcP1Odd    20.8
# rcP2Odd    3.1
# rcP3Odd    171.4
# rcRank     05
# amt        50750000
# avgWinDist 1700
# condAmt    0
# fifthCnt   4
# forthCnt   2
# fstCnt     1
# hrEngNm    ON AIR
# hrNm       온에어
# outCnt     9
# quinRate   15
# sndCnt     2
# trdCnt     2
# winRate    5
#
#
# hrName     태양제국
# hrNo       031603
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1700
# rcNo       7
# rcOrd      3
# rcP1Odd    20.8
# rcP2Odd    3.1
# rcP3Odd    171.4
# rcRank     05
# amt        61050000
# avgWinDist 1300
# condAmt    0
# fifthCnt   3
# forthCnt   1
# fstCnt     1
# hrEngNm    TAEYANG JEGUK
# hrNm       태양제국
# outCnt     10
# quinRate   19
# sndCnt     3
# trdCnt     3
# winRate    4.7
#
#
# hrName     제이에스킹
# hrNo       030357
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1700
# rcNo       7
# rcOrd      10
# rcP1Odd    20.8
# rcP2Odd    3.1
# rcP3Odd    171.4
# rcRank     05
# amt        41700000
# avgWinDist 0
# condAmt    0
# fifthCnt   5
# forthCnt   2
# fstCnt     0
# hrEngNm    J.S. KING
# hrNm       제이에스킹
# outCnt     13
# quinRate   7.6
# sndCnt     2
# trdCnt     4
# winRate    0
#
#
# hrName     투어마이더스
# hrNo       032472
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1700
# rcNo       7
# rcOrd      5
# rcP1Odd    20.8
# rcP2Odd    3.1
# rcP3Odd    171.4
# rcRank     05
# amt        95550000
# avgWinDist 1700
# condAmt    300
# fifthCnt   1
# forthCnt   5
# fstCnt     1
# hrEngNm    TOUR MIDAS
# hrNm       투어마이더스
# outCnt     9
# quinRate   29.1
# sndCnt     6
# trdCnt     2
# winRate    4.1
#
#
# hrName     쏜살같이
# hrNo       031914
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1700
# rcNo       7
# rcOrd      2
# rcP1Odd    20.8
# rcP2Odd    3.1
# rcP3Odd    171.4
# rcRank     05
# amt        130050000
# avgWinDist 1250
# condAmt    0
# fifthCnt   13
# forthCnt   4
# fstCnt     2
# hrEngNm    SSONSALGACHI
# hrNm       쏜살같이
# outCnt     32
# quinRate   6.5
# sndCnt     2
# trdCnt     8
# winRate    3.2
#
#
# hrName     킹크릭캣
# hrNo       032197
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1700
# rcNo       7
# rcOrd      1
# rcP1Odd    20.8
# rcP2Odd    3.1
# rcP3Odd    171.4
# rcRank     05
# amt        92650000
# avgWinDist 1533
# condAmt    0
# fifthCnt   3
# forthCnt   3
# fstCnt     3
# hrEngNm    KING CREEK CAT
# hrNm       킹크릭캣
# outCnt     4
# quinRate   26.6
# sndCnt     1
# trdCnt     1
# winRate    20
#
#
# hrName     환희의순간
# hrNo       032189
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1700
# rcNo       7
# rcOrd      9
# rcP1Odd    20.8
# rcP2Odd    3.1
# rcP3Odd    171.4
# rcRank     05
# amt        97850000
# avgWinDist 1300
# condAmt    0
# fifthCnt   3
# forthCnt   5
# fstCnt     2
# hrEngNm    HWANHUIUISUNGAN
# hrNm       환희의순간
# outCnt     25
# quinRate   9.5
# sndCnt     2
# trdCnt     5
# winRate    4.7
#
#
# hrName     최상질주
# hrNo       030491
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1700
# rcNo       7
# rcOrd      12
# rcP1Odd    20.8
# rcP2Odd    3.1
# rcP3Odd    171.4
# rcRank     05
# amt        39580000
# avgWinDist 1300
# condAmt    0
# fifthCnt   2
# forthCnt   4
# fstCnt     1
# hrEngNm    CHOESANG JILJU
# hrNm       최상질주
# outCnt     10
# quinRate   10.5
# sndCnt     1
# trdCnt     1
# winRate    5.2
#
#
# hrName     무패동자
# hrNo       031343
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1700
# rcNo       7
# rcOrd      7
# rcP1Odd    20.8
# rcP2Odd    3.1
# rcP3Odd    171.4
# rcRank     05
# amt        25950000
# avgWinDist 0
# condAmt    0
# fifthCnt   5
# forthCnt   4
# fstCnt     0
# hrEngNm    MUPAEDONGJA
# hrNm       무패동자
# outCnt     26
# quinRate   2.6
# sndCnt     1
# trdCnt     2
# winRate    0
#
#
# hrName     기쁜순간
# hrNo       031365
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1700
# rcNo       7
# rcOrd      11
# rcP1Odd    20.8
# rcP2Odd    3.1
# rcP3Odd    171.4
# rcRank     05
# amt        29900000
# avgWinDist 1300
# condAmt    0
# fifthCnt   2
# forthCnt   2
# fstCnt     1
# hrEngNm    GIPPEUN SUNGAN
# hrNm       기쁜순간
# outCnt     5
# quinRate   16.6
# sndCnt     1
# trdCnt     1
# winRate    8.3
#
#
# 20160103_8
# hrName     로열빅토리
# hrNo       031499
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1800
# rcNo       8
# rcOrd      2
# rcP1Odd    1.6
# rcP2Odd    1.6
# rcP3Odd    6.1
# rcRank     03
# amt        289900000
# avgWinDist 1550
# condAmt    0
# fifthCnt   2
# forthCnt   3
# fstCnt     4
# hrEngNm    ROYAL VICTORY
# hrNm       로열빅토리
# outCnt     13
# quinRate   34.3
# sndCnt     7
# trdCnt     3
# winRate    12.5
#
#
# hrName     아큘러스
# hrNo       031565
# meet       서울
# noracefl   정상
# rcDate     20160103
# rcDist     1800
# rcNo       8
# rcOrd      1
# rcP1Odd    1.6
# rcP2Odd    1.6
# rcP3Odd    6.1
# rcRank     03
# amt        200980000
# avgWinDist 1600
# condAmt    0
# fifthCnt   1
# forthCnt   3
# fstCnt     5
# hrEngNm    OCULUS
# hrNm       아큘러스
# outCnt     6
# quinRate   45
# sndCnt     4
# trdCnt     1
# winRate    25

# %%
if __name__ == '__main__':
    main()
